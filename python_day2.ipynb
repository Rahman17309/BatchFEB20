# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahman17309/BatchFEB20/blob/main/python_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#dicitoners

# %%
dict1 = {'sohail':'rahman', 'uk':'10'}

# %%
dict1
# Out:
# {'sohail': 'rahman', 'uk': '10'}

# %%
stats = pd.read_csv('/content/DemographicData.csv')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.mean()
# Out:
# <ipython-input-46-856804538210>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stats.mean()
# Birth rate        21.469928
# Internet users    42.076471
# dtype: float64

# %%
stats.median()
# Out:
# <ipython-input-47-c5d184c4f3e4>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   stats.median()
# Birth rate        19.68
# Internet users    41.00
# dtype: float64

# %%
stats.mode()
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0              Afghanistan          ABW        10.2            35.0
# 1                  Albania          AFG         NaN             NaN
# 2                  Algeria          AGO         NaN             NaN
# 3                   Angola          ALB         NaN             NaN
# 4      Antigua and Barbuda          ARE         NaN             NaN
# ..                     ...          ...         ...             ...
# 190  Virgin Islands (U.S.)          WSM         NaN             NaN
# 191     West Bank and Gaza          YEM         NaN             NaN
# 192            Yemen, Rep.          ZAF         NaN             NaN
# 193                 Zambia          ZMB         NaN             NaN
# 194               Zimbabwe          ZWE         NaN             NaN
#
#     Income Group
# 0    High income
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 190          NaN
# ...

# %%
stats.columns #rename the columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['CountryName', 'CountryCode', 'Birthrate', 'Internetusers','IncomeGroup']

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats[3:8]
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
stats.iloc[[2,5],[1,3]] #find the indexcolumns
# Out:
#   CountryCode  Internetusers
# 2         AGO           19.1
# 5         ARG           59.9

# %%
stats.Internetusers/stats.Birthrate
# Out:
# 0      7.702070
# 1      0.167362
# 2      0.415353
# 3      4.442028
# 4      7.968127
#          ...
# 190    0.607036
# 191    2.230216
# 192    0.051894
# 193    0.380519
# 194    0.517990
# Length: 195, dtype: float64

# %%
stats['New'] = stats.Internetusers/stats.Birthrate

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup       New
# 0          High income  7.702070
# 1           Low income  0.167362
# 2  Upper middle income  0.415353
# 3  Upper middle income  4.442028
# 4          High income  7.968127

# %%
# drop the columns and rows by inserting function as 
#when we delete any row we need to put the column header name and zero for rows
#when we delete any column we need to put the row header name and one for columns
stats = stats.drop("New",1)
# Out:
# <ipython-input-57-12d1eabdb376>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   stats = stats.drop("New",1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.Birthrate > 40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: Birthrate, Length: 195, dtype: bool

# %%
stats[stats.Birthrate > 40]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats.Internetusers < 10
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: Internetusers, Length: 195, dtype: bool

# %%
stats[stats.Internetusers < 10]
# Out:
#                   CountryName CountryCode  Birthrate  Internetusers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %%
#combine the data with aspecific range in it, using and function to concate the data 
stats [(stats.Birthrate > 40) & (stats.Internetusers < 10)]
# Out:
#           CountryName CountryCode  Birthrate  Internetusers IncomeGroup
# 11            Burundi         BDI     44.151            1.3  Low income
# 14       Burkina Faso         BFA     40.551            9.1  Low income
# 115              Mali         MLI     44.138            3.5  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 192  Congo, Dem. Rep.         COD     42.394            2.2  Low income

# %%
stats [(stats.Birthrate > 40) & (stats.Internetusers > 10) & (stats.IncomeGroup == 'Low income')]
# Out:
#      CountryName CountryCode  Birthrate  Internetusers IncomeGroup
# 65   Gambia, The         GMB     42.525           14.0  Low income
# 178       Uganda         UGA     43.474           16.2  Low income

# %%
stats [(stats.Birthrate > 40) & (stats.Internetusers > 10) & (stats.IncomeGroup != 'Low income')]
# Out:
#     CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 2        Angola         AGO     45.985           19.1  Upper middle income
# 128     Nigeria         NGA     40.045           38.0  Lower middle income
# 193      Zambia         ZMB     40.471           15.4  Lower middle income

# %%
stats.iat[2,2] #iat means index at specific location
# Out:
# 45.985

# %%
stats.at [2, 'Birthrate']
# Out:
# 45.985

# %%
import seaborn as sns #boxplot is used to see only outlayers

# %%
sns.boxplot(data=stats, x='IncomeGroup', y='Birthrate')
# Out:
# <AxesSubplot:xlabel='IncomeGroup', ylabel='Birthrate'>

# %%
sns.boxplot(data=stats, x='IncomeGroup', y='Internetusers')
# Out:
# <AxesSubplot:xlabel='IncomeGroup', ylabel='Internetusers'>

# %%
sns.lmplot(data=stats, x='Internetusers',y='Birthrate')

# %%
sns.lmplot(data=stats, x='Internetusers',y='Birthrate', hue = 'IncomeGroup')

# %%
sns.lmplot(data=stats, x='Internetusers',y='Birthrate', hue = 'IncomeGroup', fit_reg = False)

# %%
sns.lmplot(data=stats, x='Internetusers',y='Birthrate', hue = 'IncomeGroup', fit_reg = False, scatter_kws={'s' : 200})
